# %% [markdown]
# ### DATA PT12 - Proyecto final - Grupo 2
# #### Control de calidad de los datos del archivo Google Maps metadata_sitios de los estados de New Jersey (NJ) y New York (NY)

# %%
import glob
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
carpeta = r"datos/googlemaps/metadata-sitios"

# %%
# # Obtener la lista de archivos JSON en carpeta
# archivos_json = glob.glob(os.path.join(carpeta, "*.json"))

# # Función para leer un JSON individualmente
# def leer_json(archivo):
#     return pd.read_json(archivo, lines=True)

# # Usar múltiples hilos para leer los archivos más rápido
# with ThreadPoolExecutor() as executor:
#     df_list = list(executor.map(leer_json, archivos_json))

# # Concatenar los DataFrames en uno solo
# metadata_sitios = pd.concat(df_list, ignore_index=True)

# metadata_sitios.head()

# %%
# Obtener la lista de archivos JSON en carpeta
archivos_json = glob.glob(os.path.join(carpeta, "*.json"))

# %%
# Se guardará archivos JSON en formato pickle (binario) el cual es más rápido para futuras consultas
for archivo in archivos_json:
    df = pd.read_json(archivo, lines=True)
    df.to_pickle(archivo.replace(".json", ".pkl"))  # Guardar como .pkl

# %%
# Carga los archivos Pickle generados y los combina en un solo DataFrame.
df_list = [pd.read_pickle(archivo.replace(".json", ".pkl")) for archivo in archivos_json] # convierte el nombre de cada archivo de .json a .pkl para cargarlo correctamente.
metadata_sitio = pd.concat(df_list, ignore_index=True)

metadata_sitio.head()
# Out:
#                name                                            address  \
# 0   Porter Pharmacy  Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 1      City Textile  City Textile, 3001 E Pico Blvd, Los Angeles, C...
# 2      San Soo Dang  San Soo Dang, 761 S Vermont Ave, Los Angeles, ...
# 3      Nova Fabrics  Nova Fabrics, 2200 E 11th St, Los Angeles, CA ...
# 4  Nobel Textile Co  Nobel Textile Co, 719 E 9th St, Los Angeles, C...
#
#                                  gmap_id description   latitude   longitude  \
# 0  0x88f16e41928ff687:0x883dad4fd048e8f8        None  32.388300  -83.357100
# 1  0x80c2c98c0e3c16fd:0x29ec8a728764fdf9        None  34.018891 -118.215290
# 2  0x80c2c778e3b73d33:0xbdc58662a4a97d49        None  34.058092 -118.292130
# 3   0x80c2c89923b27a41:0x32041559418d447        None  34.023669 -118.232930
# 4  0x80c2c632f933b073:0xc31785961fe826a6        None  34.036694 -118.249421
#
#               category  avg_rating  num_of_reviews price  \
# 0           [Pharmacy]         4.9              16  None
# 1   [Textile exporter]         4.5               6  None
# 2  [Korean restaurant]         4.4              18  None
# 3       [Fabric store]         3.3               6  None
# 4       [Fabric store]         4.3               7  None
#
#                                                hours  \
# 0  [[Friday, 8AM–6PM], [Saturday, 8AM–12PM], [Sun...
# 1                                               None
# 2  [[Thursday, 6:30AM–6PM], [Friday, 6:30AM–6PM],...
# 3  [[Thursday, 9AM–5PM], [Friday, 9AM–5PM], [Satu...
# 4  [[Thursday, 9AM–5PM], [Friday, 9AM–5PM], [Satu...
#
#                                                 MISC              state  \
# 0  {'Service options': ['In-store shopping', 'Sam...  Open ⋅ Closes 6PM
# 1                                               None           Open now
# 2  {'Service options': ['Takeout', 'Dine-in', 'De...  Open ⋅ Closes 6PM
# 3  {'Service options': ['In-store shopping'], 'Pa...  Open ⋅ Closes 5PM
# 4           {'Service options': ['In-store pickup']}  Open ⋅ Closes 5PM
#
#                                     relative_results  \
# 0  [0x88f16e41929435cf:0x5b2532a2885e9ef6, 0x88f1...
# 1  [0x80c2c624136ea88b:0xb0315367ed448771, 0x80c2...
# 2  [0x80c2c78249aba68f:0x35bf16ce61be751d, 0x80c2...
# 3  [0x80c2c8811477253f:0x23a8a492df1918f7, 0x80c2...
# 4  [0x80c2c62c496083d1:0xdefa11317fe870a1, 0x80c2...
#
#                                                  url
# 0  https://www.google.com/maps/place//data=!4m2!3...
# 1  https://www.google.com/maps/place//data=!4m2!3...
# 2  https://www.google.com/maps/place//data=!4m2!3...
# 3  https://www.google.com/maps/place//data=!4m2!3...
# 4  https://www.google.com/maps/place//data=!4m2!3...

# %%
# Eliminamos columnas que no serán utilizadas

metadata_sitio = metadata_sitio.drop(columns=['price', 'hours', 'MISC', 'state', 'relative_results', 'url'])

# %%
metadata_sitio.columns
# Out:
# Index(['name', 'address', 'gmap_id', 'description', 'latitude', 'longitude',
#        'category', 'avg_rating', 'num_of_reviews'],
#       dtype='object')

# %%
metadata_sitio.head()
# Out:
#                name                                            address  \
# 0   Porter Pharmacy  Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 1      City Textile  City Textile, 3001 E Pico Blvd, Los Angeles, C...
# 2      San Soo Dang  San Soo Dang, 761 S Vermont Ave, Los Angeles, ...
# 3      Nova Fabrics  Nova Fabrics, 2200 E 11th St, Los Angeles, CA ...
# 4  Nobel Textile Co  Nobel Textile Co, 719 E 9th St, Los Angeles, C...
#
#                                  gmap_id description   latitude   longitude  \
# 0  0x88f16e41928ff687:0x883dad4fd048e8f8        None  32.388300  -83.357100
# 1  0x80c2c98c0e3c16fd:0x29ec8a728764fdf9        None  34.018891 -118.215290
# 2  0x80c2c778e3b73d33:0xbdc58662a4a97d49        None  34.058092 -118.292130
# 3   0x80c2c89923b27a41:0x32041559418d447        None  34.023669 -118.232930
# 4  0x80c2c632f933b073:0xc31785961fe826a6        None  34.036694 -118.249421
#
#               category  avg_rating  num_of_reviews
# 0           [Pharmacy]         4.9              16
# 1   [Textile exporter]         4.5               6
# 2  [Korean restaurant]         4.4              18
# 3       [Fabric store]         3.3               6
# 4       [Fabric store]         4.3               7

# %%
metadata_sitio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3025011 entries, 0 to 3025010
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   name            object
#  1   address         object
#  2   gmap_id         object
#  3   description     object
#  4   latitude        float64
#  5   longitude       float64
#  6   category        object
#  7   avg_rating      float64
#  8   num_of_reviews  int64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 207.7+ MB

# %%
# reviso que categorias hay. Busco los restaurantes de pizza
# df_mt_sitios['category'].unique()
unique_categories = pd.DataFrame(metadata_sitio["category"].explode().unique() )

# %%
unique_categories.head()
# Out:
#                    0
# 0           Pharmacy
# 1   Textile exporter
# 2  Korean restaurant
# 3       Fabric store
# 4         Restaurant

# %%
unique_resto = unique_categories[unique_categories[0].str.lower().str.contains("restaurant", na=False)]
unique_resto
# Out:
#                                0
# 2              Korean restaurant
# 4                     Restaurant
# 8         Health food restaurant
# 184            Buffet restaurant
# 238         Fast food restaurant
# ...                          ...
# 4416        Chettinad restaurant
# 4418            Sfiha restaurant
# 4433  Mutton barbecue restaurant
# 4452        Steamboat restaurant
# 4457        Sundanese restaurant
#
# [299 rows x 1 columns]

# %%
print(unique_resto.to_string())
# Out:
#                                          0
# 2                        Korean restaurant
# 4                               Restaurant
# 8                   Health food restaurant
# 184                      Buffet restaurant
# 238                   Fast food restaurant
# 310                      Family restaurant
# 311                     Seafood restaurant
# 338                   Dominican restaurant
# 356                        Taco restaurant
# 412                     Mexican restaurant
# 448                     Restaurant or cafe
# 491                   Breakfast restaurant
# 492                       Lunch restaurant
# 603                       Asian restaurant
# 604                     Hot pot restaurant
# 605                     Chinese restaurant
# 640               Mediterranean restaurant
# 670                     Takeout Restaurant
# 730                     Italian restaurant
# 734                       Ramen restaurant
# 743                    American restaurant
# 745               Modern French restaurant
# 811                       Pizza restaurant
# 885                  Vegetarian restaurant
# 887                    Delivery Restaurant
# 942                       Sushi restaurant
# 943                    Japanese restaurant
# 946                      Creole restaurant
# 947                   Caribbean restaurant
# 979                    Barbecue restaurant
# 1034                  Hamburger restaurant
# 1064                  Soul food restaurant
# 1073                    Burrito restaurant
# 1076             Latin American restaurant
# 1077                    Spanish restaurant
# 1128                Cheesesteak restaurant
# 1138                   Jamaican restaurant
# 1141                     Indian restaurant
# 1197                      Vegan restaurant
# 1199                     Kosher restaurant
# 1217          Southwestern restaurant (US)
# 1231                    Chicken restaurant
# 1307                       Thai restaurant
# 1310               Asian fusion restaurant
# 1311             Chinese noodle restaurant
# 1312                   Dumpling restaurant
# 1313                       Soup restaurant
# 1337                 Guatemalan restaurant
# 1338                   Peruvian restaurant
# 1394                     Fusion restaurant
# 1395             Middle Eastern restaurant
# 1396                    Turkish restaurant
# 1428                 Vietnamese restaurant
# 1481               New American restaurant
# 1513                       Rice restaurant
# 1518              Chicken wings restaurant
# 1563                    Hot dog restaurant
# 1577                  Ethiopian restaurant
# 1578                Gluten-free restaurant
# 1611                    Dessert restaurant
# 1624            Southeast Asian restaurant
# 1630                  Brazilian restaurant
# 1635                 Indonesian restaurant
# 1642               Restaurant supply store
# 1779                      Cajun restaurant
# 1807                     French restaurant
# 1873                        Pho restaurant
# 1895                   Filipino restaurant
# 1924                      Tapas restaurant
# 1928                    Tex-Mex restaurant
# 1948                    African restaurant
# 1949               West African restaurant
# 1977                     Brunch restaurant
# 1979                    Organic restaurant
# 2007                   Eclectic restaurant
# 2022                     German restaurant
# 2023                   European restaurant
# 2100                Singaporean restaurant
# 2105                      Hunan restaurant
# 2107           Delivery Chinese restaurant
# 2108                  Pan-Asian restaurant
# 2115                 Salvadoran restaurant
# 2122                      Halal restaurant
# 2130               Puerto Rican restaurant
# 2131               Nuevo Latino restaurant
# 2158                 Oyster bar restaurant
# 2170               East African restaurant
# 2240                Californian restaurant
# 2261                Cold noodle restaurant
# 2262             Dan Dan noodle restaurant
# 2264                Udon noodle restaurant
# 2271                      Cuban restaurant
# 2290                  Colombian restaurant
# 2333                South Asian restaurant
# 2336                  Taiwanese restaurant
# 2416                  Pakistani restaurant
# 2420                      Greek restaurant
# 2437                   Mandarin restaurant
# 2462           Central American restaurant
# 2463                 Ecuadorian restaurant
# 2470               Small plates restaurant
# 2524                Doner kebab restaurant
# 2525                       Gyro restaurant
# 2526                   Shawarma restaurant
# 2535                Fine dining restaurant
# 2541                     Hoagie restaurant
# 2596                   Lebanese restaurant
# 2604                 Neapolitan restaurant
# 2634              Southern restaurant (US)
# 2641                   Honduran restaurant
# 2643                    Laotian restaurant
# 2662               Fish & chips restaurant
# 2669     Contemporary Louisiana restaurant
# 2685       Traditional American restaurant
# 2732              Mexican torta restaurant
# 2767                 Portuguese restaurant
# 2805                      Irish restaurant
# 2864                Argentinian restaurant
# 2870         Authentic Japanese restaurant
# 2894                    Pancake restaurant
# 2895                     Jewish restaurant
# 2896                 Teppanyaki restaurant
# 2898                  Cantonese restaurant
# 2922                  Malaysian restaurant
# 2936            Korean barbecue restaurant
# 2964                    Dim sum restaurant
# 2977                   Raw food restaurant
# 2988                   Yakiniku restaurant
# 2997                   Moroccan restaurant
# 3018                    Belgian restaurant
# 3028                      Dance restaurant
# 3049          Down home cooking restaurant
# 3059                    Falafel restaurant
# 3060                   Hawaiian restaurant
# 3063               Scandinavian restaurant
# 3087         Mongolian barbecue restaurant
# 3100                    Persian restaurant
# 3145           Southern Italian restaurant
# 3174              Modern Indian restaurant
# 3185                  Norwegian restaurant
# 3187                Traditional restaurant
# 3191                     Polish restaurant
# 3197  Hong Kong style fast food restaurant
# 3208                   Canadian restaurant
# 3220                    Haitian restaurant
# 3231                    Swedish restaurant
# 3242             Japanese curry restaurant
# 3257           Eastern European restaurant
# 3258                    Russian restaurant
# 3259                  Ukrainian restaurant
# 3270           Northern Italian restaurant
# 3294                Shabu-shabu restaurant
# 3304                  Meat dish restaurant
# 3307                  Chophouse restaurant
# 3308                    Western restaurant
# 3335                        Wok restaurant
# 3347        Conveyor belt sushi restaurant
# 3356        Bar restaurant furniture store
# 3375                    Pueblan restaurant
# 3389                     Pozole restaurant
# 3392                   Nepalese restaurant
# 3403             South American restaurant
# 3411            Seafood donburi restaurant
# 3419               Cape Verdean restaurant
# 3429                Continental restaurant
# 3479                    Biryani restaurant
# 3480               Country food restaurant
# 3490                     Sundae restaurant
# 3502       North Eastern Indian restaurant
# 3503                   Po’ boys restaurant
# 3506                     Fondue restaurant
# 3511                   Tonkatsu restaurant
# 3516             Non vegetarian restaurant
# 3519                      Berry restaurant
# 3529                 Venezuelan restaurant
# 3551                     Ethnic restaurant
# 3574                Bangladeshi restaurant
# 3578                    Sichuan restaurant
# 3606                  Cambodian restaurant
# 3618                    Izakaya restaurant
# 3619   Sukiyaki and Shabu Shabu restaurant
# 3623              Indian Muslim restaurant
# 3625     Pacific Northwest restaurant (US)
# 3631                    British restaurant
# 3638                   Armenian restaurant
# 3640                     Uzbeki restaurant
# 3643                   Egyptian restaurant
# 3653                   Georgian restaurant
# 3658          French steakhouse restaurant
# 3659               Haute French restaurant
# 3660                  Pan-Latin restaurant
# 3661                 Nicaraguan restaurant
# 3662          Mid-Atlantic restaurant (US)
# 3667                    Israeli restaurant
# 3691            Modern European restaurant
# 3697                   Romanian restaurant
# 3710                   Takoyaki restaurant
# 3720                    Afghani restaurant
# 3751           Fish and seafood restaurant
# 3752                    Yucatan restaurant
# 3774                  Floridian restaurant
# 3775                   Eritrean restaurant
# 3777                    Burmese restaurant
# 3782                      Dutch restaurant
# 3783                       Momo restaurant
# 3788               Shanghainese restaurant
# 3794                     Basque restaurant
# 3795                   Porridge restaurant
# 3796                     Kerala restaurant
# 3800                     Syrian restaurant
# 3803                     Tuscan restaurant
# 3804                   Raclette restaurant
# 3825            Native American restaurant
# 3829               Self service restaurant
# 3836                 Australian restaurant
# 3837                    Chilean restaurant
# 3841          Japanese regional restaurant
# 3844                   Croatian restaurant
# 3849                 Paraguayan restaurant
# 3851                 Lithuanian restaurant
# 3854       Kyoto style Japanese restaurant
# 3856            Japanese sweets restaurant
# 3859                     Tongue restaurant
# 3860                 Polynesian restaurant
# 3868                Angler fish restaurant
# 3869          Japanized western restaurant
# 3872                   Sicilian restaurant
# 3877                   Yakitori restaurant
# 3878                       Tofu restaurant
# 3882                    Punjabi restaurant
# 3890              South African restaurant
# 3896                    Oaxacan restaurant
# 3900                  Uruguayan restaurant
# 3903                   Yemenite restaurant
# 3904                 Sri Lankan restaurant
# 3907             Indian sizzler restaurant
# 3911                    English restaurant
# 3924                Costa Rican restaurant
# 3935                New England restaurant
# 3941                      Hakka restaurant
# 3943                Korean beef restaurant
# 3944                 Korean rib restaurant
# 3950                  Bulgarian restaurant
# 3952                  Kushiyaki restaurant
# 3955                    Serbian restaurant
# 3956                       Fugu restaurant
# 3958                  Hungarian restaurant
# 3961                    Obanzai restaurant
# 3962                      Unagi restaurant
# 3970              North African restaurant
# 3984            Modern izakaya restaurants
# 3991                Pacific Rim restaurant
# 4009         Pennsylvania Dutch restaurant
# 4011                   Austrian restaurant
# 4014                      Swiss restaurant
# 4028                      Czech restaurant
# 4032                Macrobiotic restaurant
# 4046                 Catalonian restaurant
# 4050                   Tunisian restaurant
# 4052                    Soondae restaurant
# 4053       Syokudo and Teishoku restaurant
# 4055                       Goan restaurant
# 4063                   Couscous restaurant
# 4074                New Zealand restaurant
# 4081                      Roman restaurant
# 4083                    Tibetan restaurant
# 4084                    Tempura restaurant
# 4086             Offal barbecue restaurant
# 4092                 Chesapeake restaurant
# 4096                   Asturian restaurant
# 4098                Kazakhstani restaurant
# 4113                     Danish restaurant
# 4128                      Anago restaurant
# 4162                   Katsudon restaurant
# 4163            Tempura donburi restaurant
# 4186             Modern British restaurant
# 4234                    Kaiseki restaurant
# 4265                     Fujian restaurant
# 4278                    Turkmen restaurant
# 4306                      Anhui restaurant
# 4324                   Shandong restaurant
# 4329                  Madrilian restaurant
# 4366                  Icelandic restaurant
# 4374                   Yakisoba Restaurant
# 4381             Champon noodle restaurant
# 4387                      Welsh restaurant
# 4391               South Indian restaurant
# 4395                    Jiangsu restaurant
# 4397                  Valencian restaurant
# 4398                   Sukiyaki restaurant
# 4401                   Scottish restaurant
# 4403                   Provence restaurant
# 4410                    Takeout restaurant
# 4411                      Satay restaurant
# 4416                  Chettinad restaurant
# 4418                      Sfiha restaurant
# 4433            Mutton barbecue restaurant
# 4452                  Steamboat restaurant
# 4457                  Sundanese restaurant

# %%
metadata_sitio.head()
# Out:
#                name                                            address  \
# 0   Porter Pharmacy  Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 1      City Textile  City Textile, 3001 E Pico Blvd, Los Angeles, C...
# 2      San Soo Dang  San Soo Dang, 761 S Vermont Ave, Los Angeles, ...
# 3      Nova Fabrics  Nova Fabrics, 2200 E 11th St, Los Angeles, CA ...
# 4  Nobel Textile Co  Nobel Textile Co, 719 E 9th St, Los Angeles, C...
#
#                                  gmap_id description   latitude   longitude  \
# 0  0x88f16e41928ff687:0x883dad4fd048e8f8        None  32.388300  -83.357100
# 1  0x80c2c98c0e3c16fd:0x29ec8a728764fdf9        None  34.018891 -118.215290
# 2  0x80c2c778e3b73d33:0xbdc58662a4a97d49        None  34.058092 -118.292130
# 3   0x80c2c89923b27a41:0x32041559418d447        None  34.023669 -118.232930
# 4  0x80c2c632f933b073:0xc31785961fe826a6        None  34.036694 -118.249421
#
#               category  avg_rating  num_of_reviews
# 0           [Pharmacy]         4.9              16
# 1   [Textile exporter]         4.5               6
# 2  [Korean restaurant]         4.4              18
# 3       [Fabric store]         3.3               6
# 4       [Fabric store]         4.3               7

# %%
# selecciono las filas que tienen pizza restaurant
# df_mt_sitios_pizza = df_mt_sitios[df_mt_sitios['category'].apply(lambda x: 'Pizza restaurant' in x)]
# TypeError: argument of type 'NoneType' is not iterable

df_mt_sitios_pizza = metadata_sitio[metadata_sitio['category'].apply(lambda x: isinstance(x, list) and 'Pizza restaurant' in x)]

# %%
df_mt_sitios_pizza.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23814 entries, 1045 to 3025005
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            23814 non-null  object
#  1   address         23787 non-null  object
#  2   gmap_id         23814 non-null  object
#  3   description     12236 non-null  object
#  4   latitude        23814 non-null  float64
#  5   longitude       23814 non-null  float64
#  6   category        23814 non-null  object
#  7   avg_rating      23814 non-null  float64
#  8   num_of_reviews  23814 non-null  int64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 1.8+ MB

# %% [markdown]
# Hay 23814 pizza restaurants. Solo 23787 tienen direccion.

# %%
# la columna address tiene datos de nombre, direccion, localidad, codigo postal y estado
# pongo cada datos en una columna distinta porque puedo necesitarlos mas adelante
print(df_mt_sitios_pizza['address'].iloc[0])
print(df_mt_sitios_pizza['address'].iloc[5])
print(df_mt_sitios_pizza['address'].iloc[10])
print(df_mt_sitios_pizza['address'].iloc[15])
# Out:
# Sir Pizza Xpress, 201 E Broad St, Smithville, TN 37166
# Sgambati's New York Pizza, 2725 Manitowoc Rd, Green Bay, WI 54311
# Higgy's Pizza, 4104 KY-3630, Annville, KY 40402
# Alpine Pizza, 1104 U.S. 9, Schroon Lake, NY 12870

# %%
# Extract state (two uppercase letters) using regex
df_mt_sitios_pizza['state'] = df_mt_sitios_pizza['address'].str.extract(r',\s*([A-Z]{2})\s*\d{5}')

# %%
df_mt_sitios_pizza['state'].unique()
# Out:
# array(['TN', 'CO', 'MI', 'MA', 'MN', 'WI', 'AZ', 'NY', 'GA', 'KY', 'MD',
#        'AL', 'FL', 'CA', 'OR', 'PA', 'ID', 'TX', 'NJ', 'NC', 'ME', 'MO',
#        'WA', 'OH', 'NV', 'CT', 'AR', 'IN', 'DE', 'IL', 'NE', 'DC', 'UT',
#        'WY', 'OK', 'MT', 'VA', 'SC', 'IA', 'WV', 'LA', 'ND', 'MS', 'VT',
#        'KS', 'SD', 'RI', 'NH', 'HI', 'NM', nan, 'AK'], dtype=object)

# %%
# veo cuantas pizzerias hay por estado. seleccionaremos las de NY y NJ. Por la cercania con el Met Stadium
df_mt_sitios_pizza.groupby('state').count()
# Out:
#        name  address  gmap_id  description  latitude  longitude  category  \
# state
# AK       63       63       63           31        63         63        63
# AL      239      239      239          165       239        239       239
# AR      177      177      177          116       177        177       177
# AZ      325      325      325          204       325        325       325
# CA     2192     2192     2192         1357      2192       2192      2192
# CO      369      369      369          231       369        369       369
# CT      517      517      517          153       517        517       517
# DC       69       69       69           49        69         69        69
# DE       85       85       85           38        85         85        85
# FL     1264     1264     1264          674      1264       1264      1264
# GA      490      490      490          340       490        490       490
# HI       69       69       69           51        69         69        69
# IA      259      259      259          155       259        259       259
# ID      104      104      104           54       104        104       104
# IL      957      957      957          503       957        957       957
# IN      576      576      576          285       576        576       576
# KS      193      193      193          132       193        193       193
# KY      356      356      356          216       356        356       356
# LA      234      234      234          171       234        234       234
# MA      874      874      874          287       874        874       874
# MD      485      485      485          282       485        485       485
# ME      138      138      138           34       138        138       138
# MI      795      795      795          411       795        795       795
# MN      328      328      328          200       328        328       328
# MO      392      392      392          259       392        392       392
# MS      164      164      164          129       164        164       164
# MT       93       93       93           32        93         93        93
# NC      583      583      583          366       583        583       583
# ND       65       65       65           38        65         65        65
# NE      126      126      126           87       126        126       126
# NH      158      158      158           39       158        158       158
# NJ     1137     1137     1137          290      1137       1137      1137
# NM      114      114      114           68       114        114       114
# NV      209      209      209          111       209        209       209
# NY     2132     2132     2132          708      2132       2132      2132
# OH     1146     1146     1146          602      1146       1146      1146
# OK      260      260      260          158       260        260       260
# OR      221      221      221          120       221        221       221
# PA     1615     1615     1615          577      1615       1615      1615
# RI      142      142      142           43       142        142       142
# SC      231      231      231          133       231        231       231
# SD       80       80       80           54        80         80        80
# TN      388      388      388          238       388        388       388
# TX     1440     1440     1440          942      1440       1440      1440
# UT      137      137      137           93       137        137       137
# VA      648      648      648          400       648        648       648
# VT       68       68       68           20        68         68        68
# WA      358      358      358          218       358        358       358
# WI      465      465      465          216       465        465       465
# WV      199      199      199          113       199        199       199
# WY       55       55       55           40        55         55        55
#
#        avg_rating  num_of_reviews
# state
# AK             63              63
# AL            239             239
# AR            177             177
# AZ            325             325
# CA           2192            2192
# CO            369             369
# CT            517             517
# DC             69              69
# DE             85              85
# FL           1264            1264
# GA            490             490
# HI             69              69
# IA            259             259
# ID            104             104
# IL            957             957
# IN            576             576
# KS            193             193
# KY            356             356
# LA            234             234
# MA            874             874
# MD            485             485
# ME            138             138
# MI            795             795
# MN            328             328
# MO            392             392
# MS            164             164
# MT             93              93
# NC            583             583
# ND             65              65
# NE            126             126
# NH            158             158
# NJ           1137            1137
# NM            114             114
# NV            209             209
# NY           2132            2132
# OH           1146            1146
# OK            260             260
# OR            221             221
# PA           1615            1615
# RI            142             142
# SC            231             231
# SD             80              80
# TN            388             388
# TX           1440            1440
# UT            137             137
# VA            648             648
# VT             68              68
# WA            358             358
# WI            465             465
# WV            199             199
# WY             55              55

# %% [markdown]
# Hay datos de 1137 pizzerias en NJ y 2132 en NY

# %%
# selecciono las pizzerias de NJ y NY
df_mt_pizza_NJNY = df_mt_sitios_pizza[df_mt_sitios_pizza['state'].isin(['NJ', 'NY'])]

# %%
# Split address into components
df_mt_pizza_NJNY[['street_address', 'city', 'state_zip']] = df_mt_pizza_NJNY['address'].str.rsplit(", ", n=2, expand=True)

# %%
# Split state and zip code
df_mt_pizza_NJNY[['state', 'zip_code']] = df_mt_pizza_NJNY['state_zip'].str.split(" ", n=1, expand=True)

# %%
# Drop the intermediate column
df_mt_pizza_NJNY.drop(columns=['state_zip'], inplace=True)

# %%
df_mt_pizza_NJNY.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3269 entries, 2941 to 3024776
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            3269 non-null   object
#  1   address         3269 non-null   object
#  2   gmap_id         3269 non-null   object
#  3   description     998 non-null    object
#  4   latitude        3269 non-null   float64
#  5   longitude       3269 non-null   float64
#  6   category        3269 non-null   object
#  7   avg_rating      3269 non-null   float64
#  8   num_of_reviews  3269 non-null   int64
#  9   state           3269 non-null   object
#  10  street_address  3269 non-null   object
#  11  city            3269 non-null   object
#  12  zip_code        3269 non-null   object
# dtypes: float64(3), int64(1), object(9)
# memory usage: 357.5+ KB

# %%
# renombro y reordeno las columnas
df_mt_pizza_NJNY.head()
# Out:
#                     name                                            address  \
# 2941     Gino's Pizzeria  Gino's Pizzeria, 790 Washington Ave, Brooklyn,...
# 3066  Destino's Pizzeria  Destino's Pizzeria, 3909 Creek Rd, Youngstown,...
# 4699        Alpine Pizza  Alpine Pizza, 1104 U.S. 9, Schroon Lake, NY 12870
# 4947     Stewart's Shops   Stewart's Shops, 4192 NY-30, Amsterdam, NY 12010
# 8382       Al's Pizzeria  Al's Pizzeria, 201 N Main St, Gloversville, NY...
#
#                                     gmap_id  \
# 2941  0x89c25ba092402bc7:0xdfb44c575cf0a112
# 3066  0x89d360807867436d:0x91c44852e0384b78
# 4699   0x4ccab4b3af9c7c85:0x9defa19fe4e295c
# 4947  0x89de5f9627d4e973:0x5b0cbc68d57ffefb
# 8382  0x89def3a6bb7c4091:0xde094955651ec4bf
#
#                                             description   latitude  longitude  \
# 2941                                               None  40.674273 -73.963328
# 3066                                               None  43.223601 -79.017302
# 4699                                               None  43.837433 -73.761254
# 4947  Convenience chain serving its own ice cream & ...  43.017033 -74.194120
# 8382                                               None  43.056137 -74.342115
#
#                                                category  avg_rating  \
# 2941             [Pizza restaurant, Italian restaurant]         3.3
# 3066             [Pizza restaurant, Italian restaurant]         2.5
# 4699                                 [Pizza restaurant]         4.3
# 4947  [Convenience store, Alternative fuel station, ...         2.2
# 8382             [Pizza restaurant, Italian restaurant]         4.2
#
#       num_of_reviews state                       street_address          city  \
# 2941               3    NY  Gino's Pizzeria, 790 Washington Ave      Brooklyn
# 3066               4    NY    Destino's Pizzeria, 3909 Creek Rd    Youngstown
# 4699              45    NY            Alpine Pizza, 1104 U.S. 9  Schroon Lake
# 4947              15    NY          Stewart's Shops, 4192 NY-30     Amsterdam
# 8382              28    NY         Al's Pizzeria, 201 N Main St  Gloversville
#
#      zip_code
# 2941    11238
# 3066    14174
# 4699    12870
# 4947    12010
# 8382    12078

# %%
# Extract everything after the first comma and strip any extra spaces
df_mt_pizza_NJNY['cleaned_address'] = df_mt_pizza_NJNY['street_address'].str.split(", ", n=1).str[1]

# Drop the original column if necessary
df_mt_pizza_NJNY.drop(columns=['address', 'street_address', 'description', 'category'], inplace=True)

# %%
df_mt_pizza_NJNY.head()
# Out:
#                     name                                gmap_id   latitude  \
# 2941     Gino's Pizzeria  0x89c25ba092402bc7:0xdfb44c575cf0a112  40.674273
# 3066  Destino's Pizzeria  0x89d360807867436d:0x91c44852e0384b78  43.223601
# 4699        Alpine Pizza   0x4ccab4b3af9c7c85:0x9defa19fe4e295c  43.837433
# 4947     Stewart's Shops  0x89de5f9627d4e973:0x5b0cbc68d57ffefb  43.017033
# 8382       Al's Pizzeria  0x89def3a6bb7c4091:0xde094955651ec4bf  43.056137
#
#       longitude  avg_rating  num_of_reviews state          city zip_code  \
# 2941 -73.963328         3.3               3    NY      Brooklyn    11238
# 3066 -79.017302         2.5               4    NY    Youngstown    14174
# 4699 -73.761254         4.3              45    NY  Schroon Lake    12870
# 4947 -74.194120         2.2              15    NY     Amsterdam    12010
# 8382 -74.342115         4.2              28    NY  Gloversville    12078
#
#          cleaned_address
# 2941  790 Washington Ave
# 3066       3909 Creek Rd
# 4699         1104 U.S. 9
# 4947          4192 NY-30
# 8382       201 N Main St

# %%
# renombro y reordeno las columnas
df_mt_pizza_NJNY.rename(columns={'name': 'business_name', 'cleaned_address': 'address'}, inplace=True)

# %%
cols = df_mt_pizza_NJNY.columns.tolist()
cols
# Out:
# ['business_name',
#  'gmap_id',
#  'latitude',
#  'longitude',
#  'avg_rating',
#  'num_of_reviews',
#  'state',
#  'city',
#  'zip_code',
#  'address']

# %%
cols = ['gmap_id', 'business_name', 'address' , 'city', 'state', 'zip_code',  'latitude', 'longitude', 'avg_rating', 'num_of_reviews']
df_mt_pizza_NJNY = df_mt_pizza_NJNY[cols] 
df_mt_pizza_NJNY.head()
# Out:
#                                     gmap_id       business_name  \
# 2941  0x89c25ba092402bc7:0xdfb44c575cf0a112     Gino's Pizzeria
# 3066  0x89d360807867436d:0x91c44852e0384b78  Destino's Pizzeria
# 4699   0x4ccab4b3af9c7c85:0x9defa19fe4e295c        Alpine Pizza
# 4947  0x89de5f9627d4e973:0x5b0cbc68d57ffefb     Stewart's Shops
# 8382  0x89def3a6bb7c4091:0xde094955651ec4bf       Al's Pizzeria
#
#                  address          city state zip_code   latitude  longitude  \
# 2941  790 Washington Ave      Brooklyn    NY    11238  40.674273 -73.963328
# 3066       3909 Creek Rd    Youngstown    NY    14174  43.223601 -79.017302
# 4699         1104 U.S. 9  Schroon Lake    NY    12870  43.837433 -73.761254
# 4947          4192 NY-30     Amsterdam    NY    12010  43.017033 -74.194120
# 8382       201 N Main St  Gloversville    NY    12078  43.056137 -74.342115
#
#       avg_rating  num_of_reviews
# 2941         3.3               3
# 3066         2.5               4
# 4699         4.3              45
# 4947         2.2              15
# 8382         4.2              28

# %% [markdown]
# Reviso duplicados, nulos. Outliers en las columnas latitude, longitude,	avg_rating,	num_of_reviews
# Vi que en algunas columnas la latitud y la longitud no estaban bien

# %%
# reviso duplicados
df_dup = df_mt_pizza_NJNY[df_mt_pizza_NJNY.duplicated(subset=['gmap_id'], keep=False)]
df_dup = df_dup.sort_values(['gmap_id'])

print(df_dup)
# Out:
#                                      gmap_id            business_name  \
# 4699    0x4ccab4b3af9c7c85:0x9defa19fe4e295c             Alpine Pizza
# 31272   0x4ccab4b3af9c7c85:0x9defa19fe4e295c             Alpine Pizza
# 41639  0x89c2591d61cb7f73:0xccc1cb04aeccdd84  Nino's Bellissima Pizza
# 15066  0x89c2591d61cb7f73:0xccc1cb04aeccdd84  Nino's Bellissima Pizza
# 36481  0x89c25943dffb2b23:0x558b3699bfd0dcb4                    Dough
# 9908   0x89c25943dffb2b23:0x558b3699bfd0dcb4                    Dough
# 38837  0x89c259f744b20deb:0xb536eb5ee402f92f     FREEHOLD In The Park
# 12264  0x89c259f744b20deb:0xb536eb5ee402f92f     FREEHOLD In The Park
# 40006  0x89c25ab649a37525:0x91f6c1bcc70b6a91              Rax's Pizza
# 13433  0x89c25ab649a37525:0x91f6c1bcc70b6a91              Rax's Pizza
# 2941   0x89c25ba092402bc7:0xdfb44c575cf0a112          Gino's Pizzeria
# 29514  0x89c25ba092402bc7:0xdfb44c575cf0a112          Gino's Pizzeria
# 25292  0x89c25ffabe6cc3db:0xaa42b7e0387f7896   Bella pizza coffee bar
# 51865  0x89c25ffabe6cc3db:0xaa42b7e0387f7896   Bella pizza coffee bar
# 8497   0x89c2973ecbf5f8af:0xf6414e4a6b45551c     Racanelli's Pizzeria
# 35070  0x89c2973ecbf5f8af:0xf6414e4a6b45551c     Racanelli's Pizzeria
# 16998  0x89c2f79ede8e01e5:0xe1013a0ba10094a1         A Taste Of Italy
# 43571  0x89c2f79ede8e01e5:0xe1013a0ba10094a1         A Taste Of Italy
# 39420  0x89c332992853d48d:0xa6b4ab1dfc04380c        Caputo's Pizzeria
# 12847  0x89c332992853d48d:0xa6b4ab1dfc04380c        Caputo's Pizzeria
# 36312  0x89c3acab12c10d5d:0x73285fc4bd781796           Gulistan Pizza
# 9739   0x89c3acab12c10d5d:0x73285fc4bd781796           Gulistan Pizza
# 15732  0x89c71d8585020cd5:0x7c18f0acaac87f17         Pfeffer's Market
# 42305  0x89c71d8585020cd5:0x7c18f0acaac87f17         Pfeffer's Market
# 29639  0x89d360807867436d:0x91c44852e0384b78       Destino's Pizzeria
# 3066   0x89d360807867436d:0x91c44852e0384b78       Destino's Pizzeria
# 51266  0x89dd3993750980e5:0x4806bff9f951b906           Pavese's Pizza
# 24693  0x89dd3993750980e5:0x4806bff9f951b906           Pavese's Pizza
# 42986  0x89dd3e722fd95c89:0xd230cb94e596519f  My Place Pizza & Bakery
# 16413  0x89dd3e722fd95c89:0xd230cb94e596519f  My Place Pizza & Bakery
# 4947   0x89de5f9627d4e973:0x5b0cbc68d57ffefb          Stewart's Shops
# 31520  0x89de5f9627d4e973:0x5b0cbc68d57ffefb          Stewart's Shops
# 34955  0x89def3a6bb7c4091:0xde094955651ec4bf            Al's Pizzeria
# 8382   0x89def3a6bb7c4091:0xde094955651ec4bf            Al's Pizzeria
#
#                   address              city state zip_code   latitude  \
# 4699          1104 U.S. 9      Schroon Lake    NY    12870  43.837433
# 31272         1104 U.S. 9      Schroon Lake    NY    12870  43.837433
# 41639         890 2nd Ave          New York    NY    10017  40.753277
# 15066         890 2nd Ave          New York    NY    10017  40.753277
# 36481       101 Ludlow St          New York    NY    10002  40.719214
# 9908        101 Ludlow St          New York    NY    10002  40.719214
# 38837   20 Union Square W          New York    NY    10003  40.736450
# 12264   20 Union Square W          New York    NY    10003  40.736450
# 40006        4613 5th Ave          Brooklyn    NY    11220  40.646968
# 13433        4613 5th Ave          Brooklyn    NY    11220  40.646968
# 2941   790 Washington Ave          Brooklyn    NY    11238  40.674273
# 29514  790 Washington Ave          Brooklyn    NY    11238  40.674273
# 25292  4006 Junction Blvd            Queens    NY    11368  40.748822
# 51865  4006 Junction Blvd            Queens    NY    11368  40.748822
# 8497       136 S Ridge St         Rye Brook    NY    10573  41.002673
# 35070      136 S Ridge St         Rye Brook    NY    10573  41.002673
# 16998       597 Broad Ave        Ridgefield    NJ    07657  40.834104
# 43571       597 Broad Ave        Ridgefield    NJ    07657  40.834104
# 39420        418 North St        Middletown    NY    10940  41.461152
# 12847        418 North St        Middletown    NY    10940  41.461152
# 36312    783 S Orange Ave            Newark    NJ    07106  40.745207
# 9739     783 S Orange Ave            Newark    NJ    07106  40.745207
# 15732        297 Shell Rd     Carneys Point    NJ    08069  39.709561
# 42305        297 Shell Rd     Carneys Point    NJ    08069  39.709561
# 29639       3909 Creek Rd        Youngstown    NY    14174  43.223601
# 3066        3909 Creek Rd        Youngstown    NY    14174  43.223601
# 51266      2554 South Ave  Wappingers Falls    NY    12590  41.591804
# 24693      2554 South Ave  Wappingers Falls    NY    12590  41.591804
# 42986         322 Main St      Poughkeepsie    NY    12601  41.702967
# 16413         322 Main St      Poughkeepsie    NY    12601  41.702967
# 4947           4192 NY-30         Amsterdam    NY    12010  43.017033
# 31520          4192 NY-30         Amsterdam    NY    12010  43.017033
# 34955       201 N Main St      Gloversville    NY    12078  43.056137
# 8382        201 N Main St      Gloversville    NY    12078  43.056137
#
#        longitude  avg_rating  num_of_reviews
# 4699  -73.761254         4.3              45
# 31272 -73.761254         4.3              45
# 41639 -73.969366         3.3               6
# 15066 -73.969366         3.3               6
# 36481 -73.988994         5.0               4
# 9908  -73.988994         5.0               4
# 38837 -73.989926         4.2              78
# 12264 -73.989926         4.2              78
# 40006 -74.008054         4.1              28
# 13433 -74.008054         4.1              28
# 2941  -73.963328         3.3               3
# 29514 -73.963328         3.3               3
# 25292 -73.869486         4.7              18
# 51865 -73.869486         4.7              18
# 8497  -73.682569         3.5               2
# 35070 -73.682569         3.5               2
# 16998 -74.009765         3.2               8
# 43571 -74.009765         3.2               8
# 39420 -74.412270         4.3              34
# 12847 -74.412270         4.3              34
# 36312 -74.220116         3.3               8
# 9739  -74.220116         3.3               8
# 15732 -75.470117         4.9               7
# 42305 -75.470117         4.9               7
# 29639 -79.017302         2.5               4
# 3066  -79.017302         2.5               4
# 51266 -73.919643         4.5              18
# 24693 -73.919643         4.5              18
# 42986 -73.926463         4.1              88
# 16413 -73.926463         4.1              88
# 4947  -74.194120         2.2              15
# 31520 -74.194120         2.2              15
# 34955 -74.342115         4.2              28
# 8382  -74.342115         4.2              28

# %%
df_dup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34 entries, 4699 to 8382
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   gmap_id         34 non-null     object
#  1   business_name   34 non-null     object
#  2   address         34 non-null     object
#  3   city            34 non-null     object
#  4   state           34 non-null     object
#  5   zip_code        34 non-null     object
#  6   latitude        34 non-null     float64
#  7   longitude       34 non-null     float64
#  8   avg_rating      34 non-null     float64
#  9   num_of_reviews  34 non-null     int64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 2.9+ KB

# %%
# elimino los duplicados manteniendo la primera instancia
df_mt_pizza_NJNY_sindup = df_mt_pizza_NJNY.drop_duplicates(subset=['gmap_id'], keep='first')

# %% [markdown]
# Hay datos de 17 pizzerias duplicados. Los elimino

# %%
df_mt_pizza_NJNY_sindup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3252 entries, 2941 to 3024776
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   gmap_id         3252 non-null   object
#  1   business_name   3252 non-null   object
#  2   address         3239 non-null   object
#  3   city            3252 non-null   object
#  4   state           3252 non-null   object
#  5   zip_code        3252 non-null   object
#  6   latitude        3252 non-null   float64
#  7   longitude       3252 non-null   float64
#  8   avg_rating      3252 non-null   float64
#  9   num_of_reviews  3252 non-null   int64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 279.5+ KB

# %% [markdown]
# Hay 13 locales sin direccion pero tienen ciudad, estado, latitud y longitud. No los elimino </br>
# Reviso si hay Outliers en las columnas latitude, longitude,	avg_rating,	num_of_reviews

# %%
plt.figure(figsize=(4, 2))
sns.boxplot(x = 'avg_rating', data = df_mt_pizza_NJNY_sindup,
            fliersize = 10, # Outlier size
            linewidth = 3,  # Lines width
            saturation = 0.95) # Fill color saturation

# reviso valor maximo y minimo. Creo que estan en el rango correcto
print('min, ', df_mt_pizza_NJNY_sindup['avg_rating'].min())
print('max, ', df_mt_pizza_NJNY_sindup['avg_rating'].max())
print('mean, ', df_mt_pizza_NJNY_sindup['avg_rating'].mean())
# Out:
# min,  1.0
# max,  5.0
# mean,  4.110086100861008

# %% [markdown]
# avg_rating. Rango 1.0 a 5.0 Media de 4.1

# %%
# reviso outliers en num_of_reviews
plt.figure(figsize=(4, 2))
sns.boxplot(x = 'num_of_reviews', data = df_mt_pizza_NJNY_sindup,
            fliersize = 10, # Outlier size
            linewidth = 3,  # Lines width
            saturation = 0.95) # Fill color saturation
# Out:
# <Axes: xlabel='num_of_reviews'>

# %%
# algunos tienen mas de 1900 reviews
df_mt_pizza_NJNY_sindup[df_mt_pizza_NJNY_sindup['num_of_reviews'] > 1500]
# Out:
#                                        gmap_id  \
# 2535726  0x89c1869d2cf9ef11:0x64f5fd08d04f5288
# 2586355  0x89c301a10bcb8c95:0x3f650fe7631ad509
# 2627996  0x89c25985f7ec1beb:0x3c39f655da433d9d
# 2640098  0x89c19a2bc29e9fd5:0xfaaa7ec7e19ffc6f
#
#                               business_name                       address  \
# 2535726  River Rock Restaurant & Marina Bar                    1600 NJ-70
# 2586355                         Blaze Pizza  1400 Willowbrook Mall, Wayne
# 2627996                    Prince St. Pizza      27 Prince St A, New York
# 2640098                         The Sawmill  1807 Boardwalk, Seaside Park
#
#                    city   state zip_code   latitude  longitude  avg_rating  \
# 2535726  Brick Township      NJ    08724  40.097238 -74.087589         4.2
# 2586355        NJ 07470  United   States  40.888317 -74.260410         4.8
# 2627996        NY 10012  United   States  40.723084 -73.994528         4.6
# 2640098        NJ 08752  United   States  39.935696 -74.072155         4.3
#
#          num_of_reviews
# 2535726            1808
# 2586355            2208
# 2627996            4362
# 2640098            2057

# %% [markdown]
# Tiene casi el doble reviews que el segundo pero podría ser un valor válido. </br>
# Reviso si la latitud y longitud son correctas

# %%
# pip install geopy
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut

# %%
# Initialize geocoder
geolocator = Nominatim(user_agent="geo_checker")

# Function to get latitude & longitude from full address
def get_lat_long(address, city, state, zip_code):
    full_address = f"{address}, {city}, {state} {zip_code}"
    try:
        location = geolocator.geocode(full_address, timeout=10)
        if location:
            return location.latitude, location.longitude
        else:
            return None, None
    except GeocoderTimedOut:
        return None, None

# %%
# Apply the function to fetch verified coordinates
df_mt_pizza_NJNY_sindup[['verified_latitude', 'verified_longitude']] = df_mt_pizza_NJNY_sindup.apply(
    lambda row: pd.Series(get_lat_long(row['address'], row['city'], row['state'], row['zip_code'])), axis=1
)

# %%
# Compare the existing vs verified coordinates
df_mt_pizza_NJNY_sindup['lat_diff'] = abs(df_mt_pizza_NJNY_sindup['latitude'] - df_mt_pizza_NJNY_sindup['verified_latitude'])
df_mt_pizza_NJNY_sindup['long_diff'] = abs(df_mt_pizza_NJNY_sindup['longitude'] - df_mt_pizza_NJNY_sindup['verified_longitude'])

# %%
# Check rows where the difference is significant (e.g., > 0.01 degrees)
incorrect_coords = df_mt_pizza_NJNY_sindup[(df_mt_pizza_NJNY_sindup['lat_diff'] > 0.01) | (df_mt_pizza_NJNY_sindup['long_diff'] > 0.01)]

# Display incorrect rows
print(incorrect_coords[['address', 'city', 'state', 'zip_code', 
                        'latitude', 'longitude', 'verified_latitude', 'verified_longitude', 
                        'lat_diff', 'long_diff']])
# Out:
#                     address          city state zip_code   latitude  \
# 64711             761 NJ-33  East Windsor    NJ    08520  40.256906
# 104474           3501 NJ-42     Blackwood    NJ    08012  39.726715
# 183710           83 Main St        Edison    NJ    08837  40.520302
# 198247           330 NY-212    Saugerties    NY    12477  42.084625
# 233785   127 Bridgeton Pike  Mullica Hill    NJ    08062  39.725252
# ...                     ...           ...   ...      ...        ...
# 2951619   4606 Skillman Ave     Sunnyside    NY    11104  40.746294
# 2959768        362 Broadway      New York    NY    10013  40.717309
# 2982282       104 Fulton St      New York    NY    10038  40.709639
# 3000277           2920 US-6    Slate Hill    NY    10973  41.394369
# 3007440   259-21 Union Tpke        Queens    NY    11004  40.747024
#
#          longitude  verified_latitude  verified_longitude  lat_diff  long_diff
# 64711   -74.547330          40.267202          -74.483488  0.010297   0.063842
# 104474  -75.034647          39.806053          -75.057782  0.079338   0.023135
# 183710  -74.357798          40.535354          -74.318809  0.015052   0.038989
# 198247  -73.968241          42.075720          -74.024018  0.008904   0.055777
# 233785  -75.221060          39.744204          -75.222754  0.018952   0.001694
# ...            ...                ...                 ...       ...        ...
# 2951619 -73.917760          40.746173          -73.933761  0.000121   0.016001
# 2959768 -74.003482          40.749178          -73.609438  0.031869   0.394044
# 2982282 -74.006824          40.735149          -73.363726  0.025510   0.643098
# 3000277 -74.463244          41.391580          -74.478335  0.002789   0.015091
# 3007440 -73.712290          40.752371          -73.701763  0.005346   0.010527
#
# [138 rows x 10 columns]

# %%
df_mt_pizza_NJNY_sindup['lat_diff'] = abs(df_mt_pizza_NJNY_sindup['latitude'] - df_mt_pizza_NJNY_sindup['verified_latitude'])

# %%
# guardo df_mt_pizza_NJNY_sindup
df_mt_pizza_NJNY_sindup.to_parquet('datos/googlemaps/df_mt_pizza_NJNY_sindup_verif_coord.parquet' , engine='fastparquet')

# %%
# reemplazo las latitudes por las correctas
df_mt_pizza_NJNY_sindup['latitude'] = df_mt_pizza_NJNY_sindup.apply(lambda x: x['verified_latitude'] if x['lat_diff'] > 0.01 else x['latitude'], axis=1)

# %%
# reemplazo las longitudes por las correctas
df_mt_pizza_NJNY_sindup['longitude'] = df_mt_pizza_NJNY_sindup.apply(lambda x: x['verified_longitude'] if x['long_diff'] > 0.01 else x['longitude'], axis=1)

# %%
# elimino las columnas intermedias
df_mt_pizza_NJNY_sindup.drop(columns=['verified_latitude', 'verified_longitude', 'lat_diff', 'long_diff'], inplace=True)

# %%
df_mt_pizza_NJNY_sindup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3252 entries, 2941 to 3024776
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   gmap_id         3252 non-null   object
#  1   business_name   3252 non-null   object
#  2   address         3239 non-null   object
#  3   city            3252 non-null   object
#  4   state           3252 non-null   object
#  5   zip_code        3252 non-null   object
#  6   latitude        3252 non-null   float64
#  7   longitude       3252 non-null   float64
#  8   avg_rating      3252 non-null   float64
#  9   num_of_reviews  3252 non-null   int64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 279.5+ KB

# %%
# guardo df_mt_pizza_NJNY final 202502081554
df_mt_pizza_NJNY.to_parquet('datos/googlemaps/df_mt_pizza_NJNY_202502081554.parquet' , engine='fastparquet')
